x00search_engineq\xd6X\x07\x00\x00\x00diamondq\xd7X\x0f\x00\x00\x00score_thresholdq\xd8G?\xe0\x00\x00\x00\x00\x00\x00uX\x14\x00\x00\x00genome_dereplicationq\xd9}q\xda(X\x03\x00\x00\x00ANIq\xdbG?\xeeffffffX\x07\x00\x00\x00overlapq\xdcG?\xe3333333X\x0e\x00\x00\x00opt_parametersq\xddh\xb6X\x06\x00\x00\x00filterq\xde}q\xdf(X\x08\x00\x00\x00noFilterq\xe0\x89X\x06\x00\x00\x00lengthq\xe1M\x88\x13X\x0c\x00\x00\x00completenessq\xe2K2X\r\x00\x00\x00contaminationq\xe3K\nuX\x05\x00\x00\x00scoreq\xe4}q\xe5(X\x0c\x00\x00\x00completenessq\xe6K\x01X\r\x00\x00\x00contaminationq\xe7K\x05X\x03\x00\x00\x00N50q\xe8G?\xe0\x00\x00\x00\x00\x00\x00X\x06\x00\x00\x00lengthq\xe9K\x00uuX\x13\x00\x00\x00rename_mags_contigsq\xea\x88X\x0b\x00\x00\x00annotationsq\xeb]q\xec(X\t\x00\x00\x00gtdb_treeq\xedX\r\x00\x00\x00gtdb_taxonomyq\xeeX\x05\x00\x00\x00genesq\xefeX\x0b\x00\x00\x00genecatalogq\xf0}q\xf1(X\x06\x00\x00\x00sourceq\xf2X\x07\x00\x00\x00contigsq\xf3X\r\x00\x00\x00clustermethodq\xf4X\x08\x00\x00\x00linclustq\xf5X\x0c\x00\x00\x00minlength_ntq\xf6KdX\x05\x00\x00\x00minidq\xf7G?\xeeffffffX\x08\x00\x00\x00coverageq\xf8G?\xec\xcc\xcc\xcc\xcc\xcc\xcdX\x05\x00\x00\x00extraq\xf9h\xb6X\n\x00\x00\x00SubsetSizeq\xfaJ \xa1\x07\x00uX\x17\x00\x00\x00eggNOG_use_virtual_diskq\xfb\x88uX\x04\x00\x00\x00ruleq\xfcX\x07\x00\x00\x00analyzeq\xfdX\x0f\x00\x00\x00bench_iterationq\xfeNX\t\x00\x00\x00scriptdirq\xffX#\x00\x00\x00/home/kiesers/atlas_analyze/scriptsr\x00\x01\x00\x00ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir('/srv/beegfs/scratch/users/k/kiesers/Demo/Example');
######## snakemake preamble end #########

# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'retina' # on mac

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

from utils.mag_scripts import * 
from utils.barplots import * 


import altair as alt


# supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Metagenome-atlas output summary
# ===============================
#
# Here are some examples how to use the output of metagenome atlas. For repoducing this analyses see the jupter notebook Code.ipynb

# %% [markdown]
# ## Metagenome assembled genomes

# %% [markdown]
# ### Taxonomy

# %%
Tax= pd.read_table('Results/taxonomy.tsv',index_col=0)
Tax
# Out:
#                kindom        phylum        class               order  \
# user_genome
# MAG11        Bacteria    Firmicutes      Bacilli     Lactobacillales
# MAG30        Bacteria    Firmicutes      Bacilli     Lactobacillales
# MAG08        Bacteria    Firmicutes      Bacilli     Lactobacillales
# MAG40        Bacteria    Firmicutes      Bacilli  Erysipelotrichales
# MAG42        Bacteria    Firmicutes      Bacilli  Erysipelotrichales
# ...               ...           ...          ...                 ...
# MAG60        Bacteria  Bacteroidota  Bacteroidia       Bacteroidales
# MAG09        Bacteria  Bacteroidota  Bacteroidia       Bacteroidales
# MAG14        Bacteria  Bacteroidota  Bacteroidia       Bacteroidales
# MAG34        Bacteria  Bacteroidota  Bacteroidia       Bacteroidales
# MAG62        Bacteria  Bacteroidota  Bacteroidia       Bacteroidales
#
#                                 family                   genus  \
# user_genome
# ...

# %%
# create a short label for each species
Labels=Tax.ffill(axis=1).species.copy()
Labels.loc[Tax.species.isnull()]+= ' '+ Labels.index[Tax.species.isnull()]

# %% [markdown]
# ### Genome quality

# %%
genome_quality= pd.read_table('Results/genome_completeness.tsv',index_col=0)

genome_quality['Quality_Score']= genome_quality.eval('Completeness -5*Contamination')
genome_quality['Lineage']= genome_quality['Marker lineage'].map(lambda s: s.split()[0])

genome_quality['Id']= genome_quality.index

genome_quality= genome_quality.join(Tax)
genome_quality['Name']= Labels

# %%
xscale = alt.Scale(domain=(0, 15))
yscale = alt.Scale(domain=(50, 101))

alt.Chart(genome_quality).mark_circle(opacity= .4).encode(
    alt.X('Contamination', scale=xscale),
    alt.Y('Completeness', scale=yscale),
    color='phylum',
    tooltip=['Name', 'Id', 'Contamination','Completeness' ]
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Abundance

# %%
Counts= pd.read_csv('Results/counts/raw_counts_genomes.tsv',index_col=0,sep='\t').T
Counts.head()
# Out:
# Sample      MAG01   MAG02   MAG03   MAG04   MAG05   MAG06   MAG07   MAG08  \
# ERR675518   17393  117204  240075   24199   97526    7149    6495   14480
# ERR675519  281563   34570   29109  726600  201572  842380   82081  899429
# ERR675520   26242   86293  109919   18037  104119    9283   14199      25
# ERR675521  331737   36247   40084  747249  254551  936095  166398  572995
# ERR675522   23531   91372   35514   73140   36218   10569    5704      16
#
# Sample       MAG09    MAG10  ...    MAG54   MAG55   MAG56   MAG57    MAG58  \
# ERR675518  4277446  1527105  ...   837654  754481  222679  637364  2251197
# ERR675519     3267   158149  ...  1032238   42293   63801   10632  2311946
# ERR675520  2791862  1290291  ...   426057  758568  231036  281075    55038
# ERR675521    45186   186964  ...   538591   83709  163914   13811    25583
# ERR675522  5908203  1051319  ...   417819  530912  316013   15330    95070
#
# Sample      MAG59  MAG60   MAG61   MAG62   MAG63
# ...

# %% [markdown]
# ### Mapping rate

# %%
mapping_rate = pd.read_table('Results/mapping_rate.tsv',index_col=0,squeeze=True)
f,ax= plt.subplots(figsize=(2,4))
ax.set_ylim([0,1])
sns.swarmplot(y= mapping_rate,ax=ax)

ax.set_title('Mapping rate')


mapping_rate
# Out:
# ERR675518    0.716440
# ERR675519    0.624876
# ERR675520    0.734791
# ERR675521    0.568091
# ERR675522    0.728063
# ERR675523    0.573176
# ERR675524    0.740857
# ERR675525    0.553116
# ERR675526    0.708509
# ERR675527    0.735596
# ERR675528    0.555221
# ERR675529    0.729924
# ERR675530    0.621109
# ERR675531    0.550873
# ERR675532    0.545072
# Name: Mapping_rate, dtype: float64

# %% [markdown]
# ### Stats based on raw Counts
#
# There are good reasons to use rawcounts and use centric log ratios, see more in
#
# Gloor, Gregory B., Jean M. Macklaim, Vera Pawlowsky-Glahn, and Juan J. Egozcue. 2017. “Microbiome Datasets Are Compositional: And This Is Not Optional.” Frontiers in Microbiology 8 (November). Frontiers: 2224. doi:10.3389/fmicb.2017.02224.
#
#
# For differencial abundance analysis see also the same paper.

# %%
# transforme counts with centrig log ratio

data= clr(Counts)

# %%
sns.clustermap(data.T,
            row_cluster=True,cmap='RdBu_r', center=0,
             yticklabels= Labels,
              )

# %% [markdown]
# ### PCA (PCoA) of the robust aitchison distance

# %%
from sklearn.decomposition import PCA

pca= PCA()
transformed_data= pca.fit_transform(data)

# %%
pca_data= pd.DataFrame()
pca_data['PC 1']= transformed_data[:,0]
pca_data['PC 2']= transformed_data[:,1]
pca_data['Sample']= data.index



alt.Chart(pca_data).mark_circle(size=60).encode(
    x='PC 1',
    y='PC 2',
    tooltip=['Sample' ]
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Relative abundance
#
#
# For the relative abundance we take the coverage over the genome not the raw counts. This inmplicit normalizes for genome size. The coverage is calculated as the median of the coverage values calculated in 1kb blocks.

# %%
D = pd.read_table("Results/counts/median_coverage_genomes.tsv",index_col=0)
D.head()
# Out:
#            MAG01  MAG02  MAG03  MAG04  MAG05  MAG06  MAG07  MAG08    MAG09  \
# ERR675518   0.00  6.020   6.47   0.24   1.82   0.02   0.16   0.50  104.515
# ERR675519   5.59  1.320   0.00  10.47   3.36  19.18   2.53  41.03    0.000
# ERR675520   0.22  4.950   2.58   0.12   1.34   0.09   0.41   0.00   72.945
# ERR675521   5.82  1.720   0.00  12.07   3.21  21.45   5.16  25.56    1.090
# ERR675522   0.00  4.085   0.36   1.03   0.76   0.17   0.15   0.00  153.425
#
#            MAG10  ...   MAG54   MAG55  MAG56  MAG57   MAG58  MAG59  MAG60  \
# ERR675518  41.08  ...  33.375  15.760   2.67  17.44  42.300   0.31   1.41
# ERR675519   3.83  ...  42.480   0.620   0.96   0.21  44.725  10.14   0.00
# ERR675520  34.41  ...  17.345  16.875   3.22   7.94   0.170   0.34   3.02
# ERR675521   4.34  ...  21.865   1.510   2.63   0.27   0.000   8.49   0.00
# ERR675522  32.31  ...  16.600  11.800   4.89   0.00   0.000   0.92   0.00
#
#            MAG61   MAG62  MAG63
# ERR675518  21.75   7.375   0.57
# ...

# %%
#calculate relative abundance

relab = (D.T/D.sum(1)).T

# %%
# get most abundant genomes

counts_per_genome= relab.sum().sort_values()
ax= counts_per_genome[-10:].plot.bar(figsize=(10,5))

_= ax.set_xticklabels(Labels.loc[counts_per_genome.index[-10:]])
ax.set_title('Most abundant genomes')
ax.set_ylabel('Abundance [relab]')
# Out:
# Text(0, 0.5, 'Abundance [relab]')

# %% [markdown]
# ### Typical bar chart

# %%
level='family'

grouped_data =relab.groupby(Tax[level],axis=1).sum()

ax= BarPlot(grouped_data)

ax.legend_.set_title(level,{'weight':'bold'})

# %% [markdown]
# ## Functional annotation
#
#
# Relative abundance of functional annotations per sample
#
# The abundance is calculated as the sum of the relative abundance of all bacteria containing a function.

# %% [markdown]
# ### CAZy

# %%
#CAZy
CAZy_annotations_genome= pd.read_table('Results/annotations/CAZy.tsv',index_col=0)
CAZy_presence= (CAZy_annotations_genome>0).astype(int)
CAZy_presence.head()


function_relab = relab @ CAZy_presence

sns.clustermap(function_relab)

function_relab.head()
# Out:
#                AA10     CBM15     CBM20     CBM42     CBM48     CBM50  \
# ERR675518  0.001264  0.001138  0.303127  0.154332  0.942357  0.136031
# ERR675519  0.009996  0.007190  0.007372  0.000000  0.854865  0.218049
# ERR675520  0.001276  0.012479  0.362556  0.244196  0.940441  0.125164
# ERR675521  0.010213  0.006210  0.007736  0.000000  0.867113  0.179277
# ERR675522  0.001489  0.023959  0.196098  0.000102  0.958049  0.129958
#
#                CBM6     CBM73       CE1      CE10  ...      GT66       GT8  \
# ERR675518  0.057485  0.001264  0.219176  0.078272  ...  0.006327  0.094956
# ERR675519  0.084719  0.009996  0.241016  0.187480  ...  0.003498  0.121221
# ERR675520  0.131176  0.001276  0.196501  0.055319  ...  0.004490  0.103710
# ERR675521  0.125514  0.010213  0.301467  0.281992  ...  0.006194  0.129034
# ERR675522  0.106068  0.001489  0.272423  0.163352  ...  0.007062  0.078737
#
#                GT81      GT84       GT9      PL11      PL12      PL13  \
# ...

# %% [markdown]
# ### Kegg orthologs

# %%
#Kegg orthologs

Kegg_annotations_genome= pd.read_table('Results/annotations/KO.tsv',index_col=0)
Kegg_presence= (Kegg_annotations_genome>0).astype(int)
Kegg_presence.head()


function_relab = relab @ Kegg_presence

sns.clustermap(function_relab)

function_relab.head()
# Out:
#              K00001    K00002    K00003    K00004    K00005    K00008  \
# ERR675518  0.440011  0.010183  0.915543  0.013460  0.025587  0.701019
# ERR675519  0.713561  0.130889  0.929096  0.087197  0.096506  0.716695
# ERR675520  0.367651  0.015294  0.890621  0.012924  0.001744  0.707926
# ERR675521  0.597525  0.178544  0.923294  0.193653  0.072083  0.741207
# ERR675522  0.479559  0.010650  0.905161  0.014900  0.043784  0.640964
#
#              K00009    K00010    K00012    K00013  ...    K22457    K22465  \
# ERR675518  0.246648  0.003804  0.760464  0.639489  ...  0.545924  0.035164
# ERR675519  0.239012  0.034383  0.637860  0.778399  ...  0.135207  0.051593
# ERR675520  0.252043  0.012947  0.849752  0.639820  ...  0.670135  0.019768
# ERR675521  0.381346  0.050855  0.631179  0.705883  ...  0.117725  0.033035
# ERR675522  0.328581  0.014607  0.682489  0.553677  ...  0.403691  0.021122
#
#              K22466    K22468    K22476    K22477    K22491    K22503  \
# ...
